# %%
import dash
import plotly.express as px
import pandas as pd
import numpy as np
from datetime import datetime as dt

# %%
df = pd.read_excel(r'T:\1. 2021 Timesheets n Bandwidth Tracker\2. PM dashboard 2021.xlsm',  sheet_name = ['PRO DB'])

df = df['PRO DB']

# %%
df.head()
# Out:
#   Unnamed: 0  Unnamed: 1 PRO Project Master DB - 2021  \
# 0        NaN         NaN                          NaN
# 1        NaN         NaN                          NaN
# 2        NaN         NaN                          NaN
# 3        NaN  Project No                       RPT ID
# 4        NaN         NaN                 SPC21-004291
#
#                                       Unnamed: 3  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                              Deliverable title
# 4  100G+ Coherent Optical Equipment Ports – 1Q21
#
#                                       Unnamed: 4    Unnamed: 5  \
# 0                                            NaN           NaN
# 1                                            NaN           NaN
# 2                                            NaN           NaN
# 3                             Asset Family Title  Project Type
# 4  100G+ Coherent Optical Equipment Ports – 1Q21  Subscription
#
#                                       Unnamed: 7                 Unnamed: 8  \
# 0             NaN                            NaN                        NaN
# 1             NaN                            NaN                        NaN
# 2             NaN                            NaN                        NaN
# 3  Project Type 2  Is this a formatting project?       Primary Service Area
# 4      Infonetics                              Y  Service Provider Networks
#
#          Unnamed: 9  ...               Unnamed: 46  \
# 0               NaN  ...                       NaN
# 1               NaN  ...                       NaN
# 2               NaN  ...                       NaN
# 3            Pillar  ...  Is peer review required?
# 4  Service Provider  ...                         Y
#
#                                  Unnamed: 47              Unnamed: 48  \
# 0                                        NaN                      NaN
# 1                                        NaN                      NaN
# 2                                        NaN                      NaN
# 3  Is peer review done by PIC or QC Checker?  Name of person doing QC
# 4                                 QC Checker               Siraj Aziz
#
#                            Unnamed: 49  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3  Peer Review Effort Estimated (Days)
# 4                                0.125
#
#                                    Unnamed: 50             Unnamed: 51  \
# 0                                          NaN                     NaN
# 1                                          NaN                     NaN
# 2                                          NaN                     NaN
# 3  Is there an SOP available for this project?      Current SOP Status
# 4                                            N  Incorporating feedback
#
#                            Unnamed: 52         Unnamed: 53  \
# 0                                  NaN                 NaN
# 1                                  NaN                 NaN
# 2                                  NaN                 NaN
# 3  What is the SOP completion quarter?  RPT Matching Notes
# 4                                   Q2                 NaN
#
#                     Unnamed: 54 Unnamed: 55
# 0                           NaN         NaN
# 1                           NaN         NaN
# 2                           NaN         NaN
# 3  RPT ID for additional piece        Notes
# 4                           NaN         NaN
#
# [5 rows x 56 columns]

# %%
df.drop(range(0,3))
# Out:
#     Unnamed: 0  Unnamed: 1 PRO Project Master DB - 2021  \
# 3          NaN  Project No                       RPT ID
# 4          NaN         NaN                 SPC21-004291
# 5          NaN         NaN                 SPC21-004423
# 6          NaN         NaN                 SPC21-004424
# 7          NaN           1                 SPC21-004290
# ..         ...         ...                          ...
# 751        NaN           1                 SPC21-003776
# 752        NaN           1                 SPC21-003776
# 753        NaN         NaN                 SPC21-003787
# 754        NaN         NaN                 SPC21-003787
# 755        NaN           1                 IND20-002173
#
#                                          Unnamed: 3  \
# 3                                 Deliverable title
# 4     100G+ Coherent Optical Equipment Ports – 1Q21
# 5     100G+ Coherent Optical Equipment Ports – 2Q21
# 6     100G+ Coherent Optical Equipment Ports – 3Q21
# 7     100G+ Coherent Optical Equipment Ports – 4Q20
# ..                                              ...
# 751       WLAN Equipment Market Tracker Data – 4Q20
# 752  WLAN Equipment Market Tracker Data – 4Q20 [PL]
# 753        WLAN Equipment Market Tracker Data– 2Q21
# 754   WLAN Equipment Market Tracker Data– 2Q21 [PL]
# 755         Low Voltage Drives Intelligence Service
#
#                                         Unnamed: 4    Unnamed: 5  \
# 3                               Asset Family Title  Project Type
# 4    100G+ Coherent Optical Equipment Ports – 1Q21  Subscription
# 5     100G+ Coherent Optical Equipment Ports –2Q21  Subscription
# 6    100G+ Coherent Optical Equipment Ports – 3Q21  Subscription
# 7    100G+ Coherent Optical Equipment Ports – 4Q20  Subscription
# ..                                             ...           ...
# 751      WLAN Equipment Market Tracker – 4Q20 Data  Subscription
# 752      WLAN Equipment Market Tracker – 4Q20 Data  Subscription
# 753      WLAN Equipment Market Tracker – 2Q21 Data  Subscription
# 754      WLAN Equipment Market Tracker – 2Q21 Data  Subscription
# 755          Low Voltage Drives Report – 2021 Data    Consulting
#
#                                         Unnamed: 7  \
# 3    Project Type 2  Is this a formatting project?
# 4        Infonetics                              Y
# 5        Infonetics                              Y
# 6        Infonetics                              Y
# 7        Infonetics                              Y
# ..              ...                            ...
# 751      Infonetics                              Y
# 752    Product List                              N
# 753      Infonetics                              Y
# 754    Product List                              N
# 755             NaN                            NaN
#
#                                     Unnamed: 8                    Unnamed: 9  \
# 3                         Primary Service Area                        Pillar
# 4                    Service Provider Networks              Service Provider
# 5                    Service Provider Networks              Service Provider
# 6                    Service Provider Networks              Service Provider
# 7                    Service Provider Networks              Service Provider
# ..                                         ...                           ...
# 751  Service Provider Enterprise and Wholesale              Service Provider
# 752  Service Provider Enterprise and Wholesale              Service Provider
# 753  Service Provider Enterprise and Wholesale              Service Provider
# 754  Service Provider Enterprise and Wholesale              Service Provider
# 755                     Electric Motor Systems  Government and Manufacturing
#
#      ...               Unnamed: 46                                Unnamed: 47  \
# 3    ...  Is peer review required?  Is peer review done by PIC or QC Checker?
# 4    ...                         Y                                 QC Checker
# 5    ...                         Y                                 QC Checker
# 6    ...                         Y                                 QC Checker
# 7    ...                         Y                                 QC Checker
# ..   ...                       ...                                        ...
# 751  ...                         Y                                 QC Checker
# 752  ...                         N                                        NaN
# 753  ...                         Y                                        PIC
# 754  ...                         N                                        NaN
# 755  ...                         N                                        NaN
#
#                  Unnamed: 48                          Unnamed: 49  \
# 3    Name of person doing QC  Peer Review Effort Estimated (Days)
# 4                 Siraj Aziz                                0.125
# 5                 Siraj Aziz                                0.125
# 6                 Siraj Aziz                                0.125
# 7                 Siraj Aziz                                0.125
# ..                       ...                                  ...
# 751                 Jeff Ong                                0.375
# 752                      NaN                                  NaN
# 753        Amni Abdul Ghapar                                0.375
# 754                      NaN                                  NaN
# 755                      NaN                                  NaN
#
#                                      Unnamed: 50             Unnamed: 51  \
# 3    Is there an SOP available for this project?      Current SOP Status
# 4                                              N  Incorporating feedback
# 5                                              N  Incorporating feedback
# 6                                              N  Incorporating feedback
# 7                                              N  Incorporating feedback
# ..                                           ...                     ...
# 751                                            N  Incorporating feedback
# 752                                            N          Manager review
# 753                                            N  Incorporating feedback
# 754                                            N          Manager review
# 755                                            N                     NaN
#
#                              Unnamed: 52         Unnamed: 53  \
# 3    What is the SOP completion quarter?  RPT Matching Notes
# 4                                     Q2                 NaN
# 5                                     Q2                 NaN
# 6                                     Q2                 NaN
# 7                                     Q2                 NaN
# ..                                   ...                 ...
# 751                                   Q2                 NaN
# 752                                   Q2                 NaN
# 753                                   Q2                 NaN
# 754                                   Q2                 NaN
# 755                                  NaN                 NaN
#
#                       Unnamed: 54 Unnamed: 55
# 3    RPT ID for additional piece        Notes
# 4                             NaN         NaN
# 5                             NaN         NaN
# 6                             NaN         NaN
# 7                             NaN         NaN
# ..                            ...         ...
# 751                           NaN         NaN
# 752                           NaN         NaN
# 753                           NaN         NaN
# 754                           NaN         NaN
# 755                           NaN         NaN
#
# [753 rows x 56 columns]

# %%
header = df.iloc[3]

df = df[4:]

df.head()
# Out:
#   Unnamed: 0 Unnamed: 1 PRO Project Master DB - 2021  \
# 4        NaN        NaN                 SPC21-004291
# 5        NaN        NaN                 SPC21-004423
# 6        NaN        NaN                 SPC21-004424
# 7        NaN          1                 SPC21-004290
# 8        NaN          1                 SPC21-003976
#
#                                       Unnamed: 3  \
# 4  100G+ Coherent Optical Equipment Ports – 1Q21
# 5  100G+ Coherent Optical Equipment Ports – 2Q21
# 6  100G+ Coherent Optical Equipment Ports – 3Q21
# 7  100G+ Coherent Optical Equipment Ports – 4Q20
# 8   5G Consumer Broadband Pricing Database [POC]
#
#                                       Unnamed: 4    Unnamed: 5              \
# 4  100G+ Coherent Optical Equipment Ports – 1Q21  Subscription  Infonetics
# 5   100G+ Coherent Optical Equipment Ports –2Q21  Subscription  Infonetics
# 6  100G+ Coherent Optical Equipment Ports – 3Q21  Subscription  Infonetics
# 7  100G+ Coherent Optical Equipment Ports – 4Q20  Subscription  Infonetics
# 8    5G Consumer Broadband Pricing Report – 4Q20      Internal         POC
#
#   Unnamed: 7                 Unnamed: 8        Unnamed: 9  ... Unnamed: 46  \
# 4          Y  Service Provider Networks  Service Provider  ...           Y
# 5          Y  Service Provider Networks  Service Provider  ...           Y
# 6          Y  Service Provider Networks  Service Provider  ...           Y
# 7          Y  Service Provider Networks  Service Provider  ...           Y
# 8          N  Digital Consumer Services  Service Provider  ...           N
#
#   Unnamed: 47 Unnamed: 48 Unnamed: 49   Unnamed: 50             Unnamed: 51  \
# 4  QC Checker  Siraj Aziz       0.125             N  Incorporating feedback
# 5  QC Checker  Siraj Aziz       0.125             N  Incorporating feedback
# 6  QC Checker  Siraj Aziz       0.125             N  Incorporating feedback
# 7  QC Checker  Siraj Aziz       0.125             N  Incorporating feedback
# 8         NaN         NaN         NaN  Not required                     NaN
#
#   Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55
# 4          Q2         NaN         NaN         NaN
# 5          Q2         NaN         NaN         NaN
# 6          Q2         NaN         NaN         NaN
# 7          Q2         NaN         NaN         NaN
# 8           -         NaN         NaN         NaN
#
# [5 rows x 56 columns]

# %%
df = df.rename(columns=header)

df = df.dropna(axis='columns',how='all')

# %%
df.columns.tolist()
# Out:
# [nan,
#  'Project No',
#  'RPT ID',
#  'Deliverable title',
#  'Asset Family Title',
#  'Project Type',
#  'Project Type 2',
#  'Is this a formatting project?',
#  'Primary Service Area',
#  'Pillar',
#  'Project Owner',
#  'Lead Author',
#  'Supporting Author(s)',
#  'Status',
#  'C=CORE\nPC=Priority CORE\nNC=Non-CORE\nND=Non-deliverable',
#  'Is Penang Research Operations (PRO) involved?',
#  'Cadence',
#  'PRO Lead Analyst',
#  'PRO Supporting Analyst(s)',
#  'PRO Manager',
#  'Data Collection',
#  'Secondary Research',
#  'Data cleansing',
#  'Content writing',
#  'Analysis',
#  'Primary research ',
#  'Workbook updating',
#  'Report formatting',
#  'Data Visualization',
#  'Data Transformation',
#  'Process Automation',
#  'Check column',
#  'Check  column 2',
#  'PRO estimated effort (days)',
#  'Pillar Analyst estimated effort(days)',
#  'Is there any dependency to start project?',
#  'Is this project deadline estimated or actual?',
#  'Submission Status',
#  'Original  Submission Date',
#  'Actual Submission Date',
#  'Revised Submission Date',
#  'PRO / Pillar Analyst delay',
#  'Reason for delay/revision',
#  'Is this project to be submitted directly to E&P?',
#  'PLANNED SUBMISSION DATE TO E&P',
#  'CURRENT PLANNED PUB DATE',
#  'Is peer review required?',
#  'Is peer review done by PIC or QC Checker?',
#  'Name of person doing QC',
#  'Peer Review Effort Estimated (Days)',
#  'Is there an SOP available for this project?',
#  'Current SOP Status',
#  'What is the SOP completion quarter?',
#  'RPT Matching Notes',
#  'RPT ID for additional piece ',
#  'Notes']

# %%
df = df.drop(['RPT ID',
              'Asset Family Title',
              'Is this a formatting project?',
              'Primary Service Area',
              'Project Owner',
              'Lead Author',
              'Supporting Author(s)',
              'C=CORE\nPC=Priority CORE\nNC=Non-CORE\nND=Non-deliverable',
              'Is Penang Research Operations (PRO) involved?',
              'PRO Lead Analyst',
              'PRO Supporting Analyst(s)',
              'Check column',
              'Check  column 2',
              'Pillar Analyst estimated effort(days)',
              'Is there any dependency to start project?',
              'Is this project deadline estimated or actual?',
              'Submission Status',
              'Actual Submission Date',
              'Revised Submission Date',
              'PRO / Pillar Analyst delay',
              'Reason for delay/revision',
              'Is this project to be submitted directly to E&P?',
              'PLANNED SUBMISSION DATE TO E&P',
              'CURRENT PLANNED PUB DATE',
              'Is peer review required?',
              'Is peer review done by PIC or QC Checker?',
              'Name of person doing QC',
              'Peer Review Effort Estimated (Days)',
              'Is there an SOP available for this project?',
              'Current SOP Status',
              'What is the SOP completion quarter?',
              'RPT Matching Notes',
              'RPT ID for additional piece ',
              'Notes'], axis=1)

# %%
df = df.reset_index(drop=True)

df.head()
# Out:
#    NaN Project No                              Deliverable title  \
# 0  NaN        NaN  100G+ Coherent Optical Equipment Ports – 1Q21
# 1  NaN        NaN  100G+ Coherent Optical Equipment Ports – 2Q21
# 2  NaN        NaN  100G+ Coherent Optical Equipment Ports – 3Q21
# 3  NaN          1  100G+ Coherent Optical Equipment Ports – 4Q20
# 4  NaN          1   5G Consumer Broadband Pricing Database [POC]
#
#    Project Type Project Type 2            Pillar       Status    Cadence  \
# 0  Subscription     Infonetics  Service Provider     Complete  Quarterly
# 1  Subscription     Infonetics  Service Provider  Not started  Quarterly
# 2  Subscription     Infonetics  Service Provider  Not started  Quarterly
# 3  Subscription     Infonetics  Service Provider     Complete  Quarterly
# 4      Internal            POC  Service Provider     Complete    One-off
#
#   PRO Manager Data Collection  ... Content writing Analysis Primary research   \
# 0        Siva               0  ...               0        0                 0
# 1        Siva               0  ...               0        0                 0
# 2        Siva               0  ...               0        0                 0
# 3        Siva               0  ...               0        0                 0
# 4       Kalai               0  ...               0        0                 0
#
#   Workbook updating Report formatting Data Visualization Data Transformation  \
# 0                 0              1.75               0.25                   0
# 1                 0              1.75               0.25                   0
# 2                 0              1.75               0.25                   0
# 3                 0              1.75               0.25                   0
# 4                 0                 0                  0                   0
#
#   Process Automation PRO estimated effort (days) Original  Submission Date
# 0                  0                           2       2021-06-16 00:00:00
# 1                  0                           2       2021-08-27 00:00:00
# 2                  0                           2       2021-11-26 00:00:00
# 3                  0                           2       2021-03-18 00:00:00
# 4                  0                           0                       NaN
#
# [5 rows x 22 columns]

# %%
df['PRO estimated effort (days)'] = df['PRO estimated effort (days)'].fillna(0)
df['Project No'] = df['Project No'].fillna(0)
df['Original  Submission Date'] = pd.to_datetime(df['Original  Submission Date'], errors='coerce')
df = df.dropna(subset=['Original  Submission Date'])

df.head()
# Out:
#    NaN  Project No                              Deliverable title  \
# 0  NaN           0  100G+ Coherent Optical Equipment Ports – 1Q21
# 1  NaN           0  100G+ Coherent Optical Equipment Ports – 2Q21
# 2  NaN           0  100G+ Coherent Optical Equipment Ports – 3Q21
# 3  NaN           1  100G+ Coherent Optical Equipment Ports – 4Q20
# 5  NaN           0       Advertising Intelligence Database [1Q21]
#
#    Project Type Project Type 2            Pillar       Status    Cadence  \
# 0  Subscription     Infonetics  Service Provider     Complete  Quarterly
# 1  Subscription     Infonetics  Service Provider  Not started  Quarterly
# 2  Subscription     Infonetics  Service Provider  Not started  Quarterly
# 3  Subscription     Infonetics  Service Provider     Complete  Quarterly
# 5  Subscription            NaN     Entertainment  Not started  Quarterly
#
#   PRO Manager Data Collection  ... Content writing Analysis Primary research   \
# 0        Siva               0  ...               0        0                 0
# 1        Siva               0  ...               0        0                 0
# 2        Siva               0  ...               0        0                 0
# 3        Siva               0  ...               0        0                 0
# 5       Kalai               0  ...               0        0                 0
#
#   Workbook updating Report formatting Data Visualization Data Transformation  \
# 0                 0              1.75               0.25                   0
# 1                 0              1.75               0.25                   0
# 2                 0              1.75               0.25                   0
# 3                 0              1.75               0.25                   0
# 5                 0                 0                  0                   0
#
#   Process Automation PRO estimated effort (days) Original  Submission Date
# 0                  0                         2.0                2021-06-16
# 1                  0                         2.0                2021-08-27
# 2                  0                         2.0                2021-11-26
# 3                  0                         2.0                2021-03-18
# 5                0.5                         0.5                2022-01-04
#
# [5 rows x 22 columns]

# %%
df1 = pd.melt(df, 
              id_vars = ['Project No','Deliverable title', 'PRO Manager','Pillar', 'Original  Submission Date'], 
              value_vars=['Data Collection','Secondary Research', 'Data cleansing', 'Content writing', 'Analysis', 
                          'Primary research ', 'Workbook updating', 'Report formatting', 'Data Visualization', 
                          'Data Transformation', 'Process Automation'],
              var_name='Activities', value_name='value')

df1.head()
# Out:
#    Project No                              Deliverable title PRO Manager  \
# 0           0  100G+ Coherent Optical Equipment Ports – 1Q21        Siva
# 1           0  100G+ Coherent Optical Equipment Ports – 2Q21        Siva
# 2           0  100G+ Coherent Optical Equipment Ports – 3Q21        Siva
# 3           1  100G+ Coherent Optical Equipment Ports – 4Q20        Siva
# 4           0       Advertising Intelligence Database [1Q21]       Kalai
#
#              Pillar Original  Submission Date       Activities value
# 0  Service Provider                2021-06-16  Data Collection     0
# 1  Service Provider                2021-08-27  Data Collection     0
# 2  Service Provider                2021-11-26  Data Collection     0
# 3  Service Provider                2021-03-18  Data Collection     0
# 4     Entertainment                2022-01-04  Data Collection     0

# %%
df1.to_excel(r'C:\Users\GurmeetSingS\OneDrive - Informa plc\Personal\File Name.xlsx', index = False)

# %%
colors = ['rgb(68,114,196)', 'rgb(237,125,49)', 'rgb(165,165,165)', 'rgb(255,192,0)', 'rgb(95,155,213)',
          'rgb(112,173,71)', 'rgb(31,78,120)', 'rgb(112,173,71)' , 'rgb(112,2,71)', 'rgb(0,173,71)']

# %%
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Output, Input, State
import plotly.graph_objects as go

# %%
app = dash.Dash(__name__)

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)

all = np.sort(df.Pillar.unique())

all_1 = np.sort(df['PRO Manager'].unique())

app.layout=html.Div([
    html.Div([
        html.H1("PRO Project Management dashboard"),
        dcc.Tabs(id="tabs-example", value='tab-example', children=[
        dcc.Tab(label='Tab One', value='tab-1-example'), 
        dcc.Tab(label='Tab Two', value='tab-2-example'),
    ]),
    html.Div(id='tabs-content-example')
    ]),
        
])

# %%
@app.callback(Output('tabs-content-example','children'),
             Input('tabs-example','value'))

def render_content(tab):
    if tab == 'tab-1-example':
        return  html.Div([
        html.Div([
            html.Div([
                html.P('Pillar'),
                dcc.Dropdown(id='pillar-choice', options=[{'label':x, 'value':x} for x in all] + [{'label':'Select All' , 'value': 'all'}], value=['all'], multi=True, clearable = True),
                    ],className='four columns'), 
            
            html.Div([
                html.P('Manager'),
                dcc.Dropdown(id='manager-choice', options=[{'label':k, 'value':k} for k in all_1], value=[], multi=True),
                    ], className='four columns'),
            
            html.Div([
                html.P('Date Range'),
                dcc.DatePickerRange(
                id='my-date-picker-range', calendar_orientation = 'horizontal', start_date_placeholder_text="Start Period",
                    end_date_placeholder_text="End Period", min_date_allowed=(2020, 11, 31),
                    max_date_allowed=(2021, 11, 31), start_date= dt(2021,1,1).date(), end_date=dt(2021,12,31).date()),
                 html.H3(id='output-container-date-picker-range')
                    ], className='four columns'),
                    ], className='row'),   
            
        html.Div([
            dcc.Graph(id='graph1', style={'display':'inline-block', 'width' :'33%'}),
            dcc.Graph(id='graph2', style={'display':'inline-block', 'width' :'33%'}),
            dcc.Graph(id='graph3', style={'display':'inline-block', 'width' :'33%'})
            ], className='row'),
            
        html.Div([
            dcc.Graph(id='graph4', style={'display':'inline-block', 'width' :'33%'}),
            dcc.Graph(id='graph5', style={'display':'inline-block', 'width' :'33%'}),
            dcc.Graph(id='graph6', style={'display':'inline-block', 'width' :'33%'})
        ])
        
        ])
    
    elif tab == 'tab-2-example':
        return html.Div([
        html.Div([
            html.Div([
                html.P('Pillar'),
                dcc.Dropdown(id='pillar-choice', options=[{'label':x, 'value':x} for x in all] + [{'label':'Select All' , 'value': 'all'}], value=['all'], multi=True, clearable = True),
                    ],className='four columns'), 
            
            html.Div([
                html.P('Manager'),
                dcc.Dropdown(id='manager-choice', options=[{'label':k, 'value':k} for k in all_1], value=[], multi=True, clearable=False),
                    ], className='four columns'),
            
            html.Div([
                html.P('Date Range'),
                dcc.DatePickerRange(
                id='my-date-picker-range', calendar_orientation = 'horizontal', start_date_placeholder_text="Start Period",
                    end_date_placeholder_text="End Period", min_date_allowed=(2020, 11, 31),
                    max_date_allowed=(2021, 11, 31), start_date= dt(2021,1,1).date(), end_date=dt(2021,12,31).date()),
                 html.H3(id='output-container-date-picker-range')
                    ], className='four columns'),
                    ], className='row'),   
    
            
            html.Div([
            dcc.Graph(id='graph7', style={'display':'inline-block', 'width' :'33%'})
            ])
        ])

# %%
@app.callback(
    Output(component_id='graph1', component_property='figure'),
    [Input(component_id='pillar-choice', component_property='value'),
     Input(component_id='manager-choice', component_property='value'),
     Input(component_id='my-date-picker-range', component_property='start_date'),
     Input(component_id='my-date-picker-range', component_property='end_date'),]
)

def update_graph1(value_pillar, value_manager, start_date, end_date):
        if ((value_pillar == ['all']) and (len(value_manager) == 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
            
        elif ((value_pillar == ['all']) and (len(value_manager) != 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date) & 
                  df['PRO Manager'].isin(value_manager)]
            
        elif ((len(value_pillar) >= 1) and (len(value_manager) >= 1)):
            dff = df[df.Pillar.isin(value_pillar) & df['PRO Manager'].isin(value_manager) &
                     (df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        elif ((len(value_pillar) == 0) and (len(value_manager) >= 1)):
            dff =df[ df['PRO Manager'].isin(value_manager) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date)]
           
        elif ((len(value_pillar) >= 1) and (len(value_manager) == 0)):
            dff =df[df['Pillar'].isin(value_pillar) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date) ]
            
        else:
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        
        fig = go.Figure(data = [go.Pie(labels=dff['Pillar'], values = dff['PRO estimated effort (days)'], marker=dict(colors=colors), sort=False)])
        fig.update_layout (title = {'text' : "Estimated effort (days) by Pillar", 'x' : 0.4, 'y' : 0.95, 'xanchor' : 'center', 
                                    'yanchor' : 'top',
                                   'font_size' : 18})
        return fig

# %%
@app.callback(
    Output(component_id='graph2', component_property='figure'),
    [Input(component_id='pillar-choice', component_property='value'),
     Input(component_id='manager-choice', component_property='value'),
     Input(component_id='my-date-picker-range', component_property='start_date'),
     Input(component_id='my-date-picker-range', component_property='end_date'),]
)

def update_graph2(value_pillar, value_manager, start_date, end_date):
        if ((value_pillar == ['all']) and (len(value_manager) == 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
            
        elif ((value_pillar == ['all']) and (len(value_manager) != 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date) & 
                  df['PRO Manager'].isin(value_manager)]
            
        elif ((len(value_pillar) >= 1) and (len(value_manager) >= 1)):
            dff = df[df.Pillar.isin(value_pillar) & df['PRO Manager'].isin(value_manager) &
                     (df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        elif ((len(value_pillar) == 0) and (len(value_manager) >= 1)):
            dff =df[ df['PRO Manager'].isin(value_manager) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date)]
           
        elif ((len(value_pillar) >= 1) and (len(value_manager) == 0)):
            dff =df[df['Pillar'].isin(value_pillar) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date) ]
            
        else:
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        
        fig = go.Figure(data = [go.Pie(labels=dff['Cadence'], values = dff['PRO estimated effort (days)'], marker=dict(colors=colors), sort=False)])
        fig.update_layout (title = {'text' : "Estimated effort (days) by Cadence", 'x' : 0.4, 'y' : 0.95, 'xanchor' : 'center', 
                                    'yanchor' : 'top',
                                   'font_size' : 18})
        return fig

# %%
@app.callback(
    Output(component_id='graph3', component_property='figure'),
    [Input(component_id='pillar-choice', component_property='value'),
     Input(component_id='manager-choice', component_property='value'),
     Input(component_id='my-date-picker-range', component_property='start_date'),
     Input(component_id='my-date-picker-range', component_property='end_date'),]
)

def update_graph3(value_pillar, value_manager, start_date, end_date):
        if ((value_pillar == ['all']) and (len(value_manager) == 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
            
        elif ((value_pillar == ['all']) and (len(value_manager) != 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date) & 
                  df['PRO Manager'].isin(value_manager)]
            
        elif ((len(value_pillar) >= 1) and (len(value_manager) >= 1)):
            dff = df[df.Pillar.isin(value_pillar) & df['PRO Manager'].isin(value_manager) &
                     (df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        elif ((len(value_pillar) == 0) and (len(value_manager) >= 1)):
            dff =df[ df['PRO Manager'].isin(value_manager) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date)]
           
        elif ((len(value_pillar) >= 1) and (len(value_manager) == 0)):
            dff =df[df['Pillar'].isin(value_pillar) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date) ]
            
        else:
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        
        fig = go.Figure(data = [go.Pie(labels=dff['Project Type'], values = dff['PRO estimated effort (days)'], marker=dict(colors=colors), sort=False)])
        fig.update_layout (title = {'text' : "Estimated effort (days) by Project Type", 'x' : 0.4, 'y' : 0.95, 'xanchor' : 'center', 
                                    'yanchor' : 'top',
                                   'font_size' : 18})
        return fig

# %%
@app.callback(
    Output(component_id='graph4', component_property='figure'),
    [Input(component_id='pillar-choice', component_property='value'),
     Input(component_id='manager-choice', component_property='value'),
     Input(component_id='my-date-picker-range', component_property='start_date'),
     Input(component_id='my-date-picker-range', component_property='end_date'),]
)

def update_graph4(value_pillar, value_manager, start_date, end_date):
        if ((value_pillar == ['all']) and (len(value_manager) == 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
            
        elif ((value_pillar == ['all']) and (len(value_manager) != 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date) & 
                  df['PRO Manager'].isin(value_manager)]
            
        elif ((len(value_pillar) >= 1) and (len(value_manager) >= 1)):
            dff = df[df.Pillar.isin(value_pillar) & df['PRO Manager'].isin(value_manager) &
                     (df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        elif ((len(value_pillar) == 0) and (len(value_manager) >= 1)):
            dff =df[ df['PRO Manager'].isin(value_manager) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date)]
           
        elif ((len(value_pillar) >= 1) and (len(value_manager) == 0)):
            dff =df[df['Pillar'].isin(value_pillar) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date) ]
            
        else:
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        
        fig = go.Figure(data = [go.Pie(labels=dff['Pillar'], values = dff['Project No'], marker=dict(colors=colors), sort=False)])
        fig.update_layout (title = {'text' : "Number of projects by Pillar", 'x' : 0.4, 'y' : 0.95, 'xanchor' : 'center', 
                                    'yanchor' : 'top',
                                   'font_size' : 18})
        return fig

# %%
@app.callback(
    Output(component_id='graph5', component_property='figure'),
    [Input(component_id='pillar-choice', component_property='value'),
     Input(component_id='manager-choice', component_property='value'),
     Input(component_id='my-date-picker-range', component_property='start_date'),
     Input(component_id='my-date-picker-range', component_property='end_date'),]
)

def update_graph5(value_pillar, value_manager, start_date, end_date):
        if ((value_pillar == ['all']) and (len(value_manager) == 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
            
        elif ((value_pillar == ['all']) and (len(value_manager) != 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date) & 
                  df['PRO Manager'].isin(value_manager)]
            
        elif ((len(value_pillar) >= 1) and (len(value_manager) >= 1)):
            dff = df[df.Pillar.isin(value_pillar) & df['PRO Manager'].isin(value_manager) &
                     (df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        elif ((len(value_pillar) == 0) and (len(value_manager) >= 1)):
            dff =df[ df['PRO Manager'].isin(value_manager) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date)]
           
        elif ((len(value_pillar) >= 1) and (len(value_manager) == 0)):
            dff =df[df['Pillar'].isin(value_pillar) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date) ]
            
        else:
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        
        fig = go.Figure(data = [go.Pie(labels=dff['Cadence'], values = dff['Project No'], marker=dict(colors=colors), sort=False)])
        fig.update_layout (title = {'text' : "Number of projects by Cadence", 'x' : 0.4, 'y' : 0.95, 'xanchor' : 'center', 
                                    'yanchor' : 'top',
                                   'font_size' : 18})
        return fig

# %%
@app.callback(
    Output(component_id='graph6', component_property='figure'),
    [Input(component_id='pillar-choice', component_property='value'),
     Input(component_id='manager-choice', component_property='value'),
     Input(component_id='my-date-picker-range', component_property='start_date'),
     Input(component_id='my-date-picker-range', component_property='end_date'),]
)

def update_graph6(value_pillar, value_manager, start_date, end_date):
        if ((value_pillar == ['all']) and (len(value_manager) == 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
            
        elif ((value_pillar == ['all']) and (len(value_manager) != 0)):
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date) & 
                  df['PRO Manager'].isin(value_manager)]
            
        elif ((len(value_pillar) >= 1) and (len(value_manager) >= 1)):
            dff = df[df.Pillar.isin(value_pillar) & df['PRO Manager'].isin(value_manager) &
                     (df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        elif ((len(value_pillar) == 0) and (len(value_manager) >= 1)):
            dff =df[ df['PRO Manager'].isin(value_manager) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date)]
           
        elif ((len(value_pillar) >= 1) and (len(value_manager) == 0)):
            dff =df[df['Pillar'].isin(value_pillar) & (df['Original  Submission Date']>=start_date) & 
                    (df['Original  Submission Date']<=end_date) ]
            
        else:
            dff = df[(df['Original  Submission Date']>=start_date) & (df['Original  Submission Date']<=end_date)]
        
        
        fig = go.Figure(data = [go.Pie(labels=dff['Project Type'], values = dff['Project No'], marker=dict(colors=colors), sort=False)])
        fig.update_layout (title = {'text' : "Number of projects by Project Type", 'x' : 0.4, 'y' : 0.95, 'xanchor' : 'center', 
                                    'yanchor' : 'top',
                                   'font_size' : 18})
        return fig

# %%
@app.callback(
    Output(component_id='graph7', component_property='figure'),
    [Input(component_id='pillar-choice', component_property='value'),
     Input(component_id='manager-choice', component_property='value'),
     Input(component_id='my-date-picker-range', component_property='start_date'),
     Input(component_id='my-date-picker-range', component_property='end_date'),]
)

def update_graph7(value_pillar, value_manager, start_date, end_date):
        if ((value_pillar == ['all']) and (len(value_manager) == 0)):
            dff = df1[(df1['Original  Submission Date']>=start_date) & (df1['Original  Submission Date']<=end_date)]
            
        elif ((value_pillar == ['all']) and (len(value_manager) != 0)):
            dff = df1[(df1['Original  Submission Date']>=start_date) & (df1['Original  Submission Date']<=end_date) & 
                  df1['PRO Manager'].isin(value_manager)]
            
        elif ((len(value_pillar) >= 1) and (len(value_manager) >= 1)):
            dff = df1[df1.Pillar.isin(value_pillar) & df1['PRO Manager'].isin(value_manager) &
                     (df1['Original  Submission Date']>=start_date) & (df1['Original  Submission Date']<=end_date)]
        
        elif ((len(value_pillar) == 0) and (len(value_manager) >= 1)):
            dff =df1[df1['PRO Manager'].isin(value_manager) & (df1['Original  Submission Date']>=start_date) & 
                    (df1['Original  Submission Date']<=end_date)]
           
        elif ((len(value_pillar) >= 1) and (len(value_manager) == 0)):
            dff =df1[df1['Pillar'].isin(value_pillar) & (df1['Original  Submission Date']>=start_date) & 
                    (df1['Original  Submission Date']<=end_date) ]
            
        else:
            dff = df1[(df1['Original  Submission Date']>=start_date) & (df1['Original  Submission Date']<=end_date)]
        
        
        fig = go.Figure(data = [go.Pie(labels=dff['Activities'], values = dff['value'], marker=dict(colors=colors),
                                sort=False)])
        fig.update_layout (title = {'text' : "Estimated effort (days) by Activities", 'x' : 0.4, 'y' : 0.95, 
                                    'xanchor' : 'center', 'yanchor' : 'top', 'font_size' : 18})
        
        return fig

# %%
server = app.server

if __name__=='__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/Sep/2021 15:18:41] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:42] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:42] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:42] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:44] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Sep/2021 15:18:44] "POST /_dash-update-component HTTP/1.1" 200 -
